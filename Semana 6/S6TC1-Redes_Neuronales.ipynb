# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Redes Neuronales
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de redes neuronales de una capa y multicapa. El taller está constituido por 4 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción probabilidad de admisión a la universidad
#
# En este taller se usará el conjunto de datos de admisiones a una universidad proveniente de la base de datos de Kaggle. Cada observación contiene la probabilidad de que un estudiante sea admitido por la universidad, dadas distintas variables predictoras como el puntaje del examén TOEFL y GRE, el promedio (GPA), entre otras. El objetivo es predecir la probabilidad de admissión de cada estudiante. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/mohansacharya/graduate-admissions).

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# Running cells with 'Python 3.6.8' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/lumor/AppData/Local/Programs/Python/Python36/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (2.0.2)
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
# Requirement already satisfied: numpy>=1.22.4; python_version < "3.11" in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tzdata, pytz, pandas
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from matplotlib) (25.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.58.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting pillow>=8
#   Downloading pillow-11.2.1-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\lumor\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.21.0)
# Installing collected packages: kiwisolver, pyparsing, cycler, fonttools, pillow, importlib-resources, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.58.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.2.1 pyparsing-3.2.3
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install keras
# Out:
# Collecting keras
#   Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: packaging in c:\users\lumor\appdata\roaming\python\python39\site-packages (from keras) (25.0)
# Collecting namex
#   Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: numpy in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from keras) (2.0.2)
# Collecting absl-py
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Collecting optree
#   Downloading optree-0.15.0-cp39-cp39-win_amd64.whl (292 kB)
# Collecting ml-dtypes
#   Downloading ml_dtypes-0.5.1-cp39-cp39-win_amd64.whl (209 kB)
# Collecting rich
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Collecting h5py
#   Downloading h5py-3.13.0-cp39-cp39-win_amd64.whl (3.0 MB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from optree->keras) (4.13.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from rich->keras) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, absl-py, optree, ml-dtypes, mdurl, markdown-it-py, rich, h5py, keras
# Successfully installed absl-py-2.2.2 h5py-3.13.0 keras-3.9.2 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.9 optree-0.15.0 rich-14.0.0
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (2.0.2)
# Installing collected packages: scipy, threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.0 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp39-cp39-win_amd64.whl (375.7 MB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.2-cp39-cp39-win_amd64.whl (38 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3
#   Downloading protobuf-5.29.4-cp39-cp39-win_amd64.whl (434 kB)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.5.1)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.71.0-cp39-cp39-win_amd64.whl (4.3 MB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.0.2)
# Collecting tensorboard~=2.19.0
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.13.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from tensorflow) (1.17.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: packaging in c:\users\lumor\appdata\roaming\python\python39\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: setuptools in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (49.2.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1; python_version < "3.12"
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.9.2)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: optree in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: rich in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp39-cp39-win_amd64.whl (105 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\lumor\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow) (8.7.0)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp39-cp39-win_amd64.whl (15 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\lumor\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.19.0->tensorflow) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lumor\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Installing collected packages: wrapt, libclang, protobuf, wheel, astunparse, grpcio, markdown, MarkupSafe, werkzeug, tensorboard-data-server, tensorboard, google-pasta, opt-einsum, flatbuffers, gast, tensorflow-io-gcs-filesystem, termcolor, charset-normalizer, idna, urllib3, certifi, requests, tensorflow
# Successfully installed MarkupSafe-3.0.2 astunparse-1.6.3 certifi-2025.4.26 charset-normalizer-3.4.2 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 idna-3.10 libclang-18.1.1 markdown-3.8 opt-einsum-3.4.0 protobuf-5.29.4 requests-2.32.3 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.1.0 urllib3-2.4.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2
#   WARNING: The script wheel.exe is installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe and toco.exe are installed in 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip uninstall keras keras-nightly keras-preprocessing keras-applications tensorflow -y
# Out:
# Found existing installation: keras 3.9.2
# Uninstalling keras-3.9.2:
#   Successfully uninstalled keras-3.9.2
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# WARNING: Skipping keras-nightly as it is not installed.
# WARNING: Skipping keras-preprocessing as it is not installed.
# WARNING: Skipping keras-applications as it is not installed.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\cli\base_command.py", line 228, in _main
#     status = self.run(options, args)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\commands\uninstall.py", line 93, in run
#     uninstall_pathset.commit()
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\req\req_uninstall.py", line 450, in commit
#     self._moved_paths.commit()
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\req\req_uninstall.py", line 290, in commit
#     save_dir.cleanup()
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\utils\temp_dir.py", line 199, in cleanup
#     rmtree(ensure_text(self._path))
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\retrying.py", line 49, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\retrying.py", line 212, in call
#     raise attempt.get()
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\retrying.py", line 247, in get
#     six.reraise(self.value[0], self.value[1], self.value[2])
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\six.py", line 703, in reraise
#     raise value
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_vendor\retrying.py", line 200, in call
#     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\utils\misc.py", line 138, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors,
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\shutil.py", line 737, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\shutil.py", line 610, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\shutil.py", line 610, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\shutil.py", line 615, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\shutil.py", line 613, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 5] Acceso denegado: 'C:\\Users\\lumor\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\~ensorflow\\python\\client\\_pywrap_tf_session.pyd'

# %%
# !{sys.executable} -m pip install keras==2.3.1 tensorflow==1.14
# Out:
# Collecting keras==2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.14 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow==1.14
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\lumor\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# Importación librerías
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from keras import initializers
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Importación librerías
#       2 import numpy as np
# ----> 3 import keras
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\api\activations\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import celu
#       4 from keras.src.activations.activations import elu
#       5 from keras.src.activations.activations import exponential
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\__init__.py:10
#       7     import torch
#       9 from keras.src.api_export import keras_export
# ---> 10 from keras.src.backend.common.dtypes import result_type
#      11 from keras.src.backend.common.keras_tensor import KerasTensor
#      12 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\common\__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import Variable as KerasVariable
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\common\dtypes.py:5
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\common\variables.py:12
#      10 from keras.src.backend.common.stateless_scope import in_stateless_scope
#      11 from keras.src.utils.module_utils import tensorflow as tf
# ---> 12 from keras.src.utils.naming import auto_name
#      15 class Variable:
#      16     """Represents a backend-agnostic variable in Keras.
#      17
#      18     A `Variable` acts as a container for state. It holds a tensor value and can
#    (...)
#      88     ```
#      89     """
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\__init__.py:1
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#       3 from keras.src.utils.file_utils import get_file
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\audio_dataset_utils.py:4
#       1 import numpy as np
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#       6 from keras.src.utils.module_utils import tensorflow_io as tfio
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\dataset_utils.py:9
#       5 from multiprocessing.pool import ThreadPool
#       7 import numpy as np
# ----> 9 from keras.src import tree
#      10 from keras.src.api_export import keras_export
#      11 from keras.src.utils import io_utils
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\tree\__init__.py:1
# ----> 1 from keras.src.tree.tree_api import assert_same_paths
#       2 from keras.src.tree.tree_api import assert_same_structure
#       3 from keras.src.tree.tree_api import flatten
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\tree\tree_api.py:8
#       5 from keras.src.utils.module_utils import optree
#       7 if optree.available:
# ----> 8     from keras.src.tree import optree_impl as tree_impl
#       9 elif dmtree.available:
#      10     from keras.src.tree import dmtree_impl as tree_impl
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\tree\optree_impl.py:13
#      11 # Register backend-specific node classes
#      12 if backend() == "tensorflow":
# ---> 13     from tensorflow.python.trackable.data_structures import ListWrapper
#      14     from tensorflow.python.trackable.data_structures import _DictWrapper
#      16     optree.register_pytree_node(
#      17         ListWrapper,
#      18         lambda x: (x, None),
#      19         lambda metadata, children: ListWrapper(list(children)),
#      20         namespace="keras",
#      21     )
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\framework\ops.py:5929
#    5923   except LookupError:
#    5924     return None
#    5927 def get_to_proto_function(
#    5928     collection_name,
# -> 5929 ) -> Optional[Callable[[Any], message.Message]]:
#    5930   """Returns the to_proto function for collection_name."""
#    5931   try:
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:243, in _tp_cache.<locals>.inner(*args, **kwds)
#     241 except TypeError:
#     242     pass  # All real errors (not unhashable args) are raised below.
# --> 243 return func(*args, **kwds)
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:316, in _SpecialForm.__getitem__(self, parameters)
#     314 @_tp_cache
#     315 def __getitem__(self, parameters):
# --> 316     return self._getitem(self, parameters)
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:433, in Optional(self, parameters)
#     428 """Optional type.
#     429
#     430 Optional[X] is equivalent to Union[X, None].
#     431 """
#     432 arg = _type_check(parameters, f"{self} requires a single type.")
# --> 433 return Union[arg, type(None)]
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:243, in _tp_cache.<locals>.inner(*args, **kwds)
#     241 except TypeError:
#     242     pass  # All real errors (not unhashable args) are raised below.
# --> 243 return func(*args, **kwds)
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:316, in _SpecialForm.__getitem__(self, parameters)
#     314 @_tp_cache
#     315 def __getitem__(self, parameters):
# --> 316     return self._getitem(self, parameters)
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:421, in Union(self, parameters)
#     419 msg = "Union[arg, ...]: each arg must be a type."
#     420 parameters = tuple(_type_check(p, msg) for p in parameters)
# --> 421 parameters = _remove_dups_flatten(parameters)
#     422 if len(parameters) == 1:
#     423     return parameters[0]
#
# File c:\Users\lumor\AppData\Local\Programs\Python\Python39\lib\typing.py:215, in _remove_dups_flatten(parameters)
#     213         params.append(p)
#     214 # Weed out strict duplicates, preserving the first of each occurrence.
# --> 215 all_params = set(params)
#     216 if len(all_params) < len(params):
#     217     new_params = []
#
# TypeError: unhashable type: 'list'

# %%
# Carga de datos de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/universityGraduateAdmissions.csv', index_col=0)
data.head()

# %%
# Hitogramas de las varaibles del dataset
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
# Definición de variables predictoras (X)
X = data.drop(data.columns[-1], axis=1)
# Definición de variable de interés (y)
Y = data[data.columns[-1]]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# %% [markdown]
# ## Punto 1 - Red Neuronal de una capa
#
# En la celda 1 creen una **red neuronal de una capa** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes, usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador y el número de épocas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 1

# %% [markdown]
# ## Punto 2 - Red Neuronal multicapa
#
# En la celda 2 creen una **red neuronal con dos capas** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 2

# %% [markdown]
# ## Punto 3  - Red Neuronal multicapa
#
# En la celda 3 creen **una red neuronal con más de una capa con la librería Keras, usando early stopping y dropout,** que prediga la probabilidad de admisión de los estudiantes con los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 3

# %% [markdown]
# ## Punto 4 - Comparación y análisis de resultados
#
# En la celda 4 comparen los resultados obtenidos de las diferentes redes y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 4
